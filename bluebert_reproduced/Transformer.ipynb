# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\rjb96\\Documents\\fourth_semester\\Capstone\\bluebert'

# %%
path = 'C://Users//rjb96//Documents//fourth_semester//Capstone//bluebert/bluebert_model//'

# %%
checkpoint_path = path + 'bert_model.ckpt '
bert_config_path = path + 'bert_config.json'
pytorch_dump_path= path + 'pytorch_model.bin'

# %%
# !python convert_bert_original_tf_checkpoint_to_pytorch.py \
--tf_checkpoint_path=checkpoint_path \
--bert_config_file=bert_config_path \
--pytorch_dump_path=pytorch_dump_path
# Out:
# Traceback (most recent call last):
#   File "convert_bert_original_tf_checkpoint_to_pytorch.py", line 54, in <module>
#     convert_tf_checkpoint_to_pytorch(args.tf_checkpoint_path, args.bert_config_file, args.pytorch_dump_path)
#   File "convert_bert_original_tf_checkpoint_to_pytorch.py", line 24, in convert_tf_checkpoint_to_pytorch
#     config = BertConfig.from_json_file(bert_config_file)
#   File "C:\Users\rjb96\AppData\Local\Continuum\anaconda3\lib\site-packages\transformers\configuration_utils.py", line 504, in from_json_file
#     config_dict = cls._dict_from_json_file(json_file)
#   File "C:\Users\rjb96\AppData\Local\Continuum\anaconda3\lib\site-packages\transformers\configuration_utils.py", line 509, in _dict_from_json_file
#     with open(json_file, "r", encoding="utf-8") as reader:
# FileNotFoundError: [Errno 2] No such file or directory: 'bert_config_path'

# %%
bert_config_file
# Out:
# 'C://Users//rjb96//Documents//fourth_semester//Capstone//bluebert/bluebert_model/bert_config.json'

# %%
# %ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is E0B8-68D6
#
#  Directory of C:\Users\rjb96\Documents\fourth_semester\Capstone\bluebert
#
# 03/03/2021  09:42 PM    <DIR>          .
# 03/03/2021  09:42 PM    <DIR>          ..
# 02/28/2021  12:25 PM             2,487 .gitignore
# 03/03/2021  09:28 PM    <DIR>          .ipynb_checkpoints
# 02/28/2021  03:32 PM    <DIR>          bert
# 02/28/2021  04:05 PM    <DIR>          bluebert
# 02/28/2021  01:13 PM    <DIR>          bluebert_model
# 03/03/2021  09:28 PM             1,577 convert_bert_original_tf_checkpoint_to_pytorch.py
# 03/03/2021  09:12 PM    <DIR>          datasets
# 02/28/2021  12:25 PM    <DIR>          elmo
# 02/28/2021  12:25 PM             1,297 LICENSE.txt
# 02/28/2021  12:25 PM    <DIR>          mribert
# 02/28/2021  12:25 PM    <DIR>          mt-bluebert
# 02/28/2021  10:33 PM    <DIR>          output
# 02/28/2021  03:45 PM                 0 python
# 02/28/2021  12:25 PM             9,108 README.md
# ...

# %%
from transformers import BertConfig, BertForPreTraining, load_tf_weights_in_bert

# %%
config = BertConfig.from_json_file(bert_config_path)

# %%
import argparse

import torch

from transformers import BertConfig, BertForPreTraining, load_tf_weights_in_bert
from transformers.utils import logging


logging.set_verbosity_info()



# In[ ]:

# %%
def convert_tf_checkpoint_to_pytorch(tf_checkpoint_path, bert_config_file, pytorch_dump_path):
    # Initialise PyTorch model
    config = BertConfig.from_json_file(bert_config_file)
    print("Building PyTorch model from configuration: {}".format(str(config)))
    model = BertForPreTraining(config)

    # Load weights from tf checkpoint
    load_tf_weights_in_bert(model, config, tf_checkpoint_path)

    # Save pytorch-model
    print("Save PyTorch model to {}".format(pytorch_dump_path))
    torch.save(model.state_dict(), pytorch_dump_path)

# %%
convert_tf_checkpoint_to_pytorch(checkpoint_path,bert_config_path,pytorch_dump_path)
# Out:
# Building PyTorch model from configuration: BertConfig {
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.3.3",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
# Converting TensorFlow checkpoint from C:\Users\rjb96\Documents\fourth_semester\Capstone\bluebert\bluebert_model\bert_model.ckpt
# Loading TF weight bert/embeddings/LayerNorm/beta with shape [768]
# Loading TF weight bert/embeddings/LayerNorm/beta/adam_m with shape [768]
# Loading TF weight bert/embeddings/LayerNorm/beta/adam_v with shape [768]
# ...
